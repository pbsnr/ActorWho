# %% [markdown]
# # ACTOR WHO

# %% [markdown]
# ### Netflix film name

# %%
import requests
from bs4 import BeautifulSoup

# %%
page = requests.get("https://www.netflix.com/watch/70250213?trackId=14170286&tctx=7%2C1%2Cf19da7c2-b4c6-4d38-8462-535983d4c67a-90078927%2C7be0cb14-ab37-4222-88b5-5e7e754ccb76_71759217X3XX1611081880258%2C7be0cb14-ab37-4222-88b5-5e7e754ccb76_ROOT%2C")
soup = BeautifulSoup(page.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE doctype html>
# ...

# %%
movies = soup.findAll('title')
title = str(movies)

# %%
title = title.replace('[<title>','')
title = title.replace('| Netflix</title>]','')

# %%
title
# Out:
# 'Asterix: The 12 Tasks '

# %% [markdown]
# ### Prime Film Name

# %%
page = requests.get("https://www.primevideo.com/detail/0K1WV322IHDWN1GSYLU92V2VOI/ref=atv_hm_hom_1_c_r1Fy1u_3_8")
soup = BeautifulSoup(page.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE doctype html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en">
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <link crossorigin="" href="https://m.media-amazon.com" rel="preconnect"/>
# <link href="https://m.media-amazon.com/images/I/71RgwEQJ7gL.css?commons" onerror="typeof DVWebNodeAssetError === 'function' &amp;&amp; DVWebNodeAssetError('nav', 'https://m.media-amazon.com/images/I/71RgwEQJ7gL.css?commons')" rel="stylesheet" type="text/css"/>
# <script async="" crossorigin="anonymous" defer="" onerror="typeof DVWebNodeAssetError === 'function' &amp;&amp; DVWebNodeAssetError('nav', 'https://m.media-amazon.com/images/I/81+Vzs4ikxL.js?commons')" src="https://m.media-amazon.com/images/I/81+Vzs4ikxL.js?commons" type="text/javascript"></script>
# ...

# %%
movies = soup.findAll('title')
title = str(movies[0])

# %%
title = title.replace('<title>Prime Video:','')
title = title.replace('</title>','')

# %%
title
# Out:
# ' Rise of the Planet of Apes'

# %% [markdown]
# ### FINAL SCRIPT

# %%
import requests
from bs4 import BeautifulSoup
link = ''
if 'netflix.com' in link:
    page = requests.get(link)
    soup = BeautifulSoup(page.content, 'html.parser')
    movies = soup.findAll('title')
    title = str(movies)
    title = title.replace('[<title>','')
    title = title.replace('| Netflix</title>]','')
    print('Movie title is: ',title)
if 'primevideo.com' in link: 
    page = requests.get(link)
    soup = BeautifulSoup(page.content, 'html.parser')
    movies = soup.findAll('title')
    title = str(movies[0])
    title = title.replace('<title>Prime Video:','')
    title = title.replace('</title>','')
    print('Movie title is: ',title)
else:
    print('Application requires Netflix or PrimeVideo only')
# Out:
# Application requires Netflix or PrimeVideo only
